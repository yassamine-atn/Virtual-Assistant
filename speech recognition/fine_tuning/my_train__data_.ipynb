             " On Monday, Salinas Products, a large food distributor based in Mexico City, announced its plans to acquire the Pablo’s restaurant chain. Pablo Benavidez, the chain’s owner, had been considering holding an auction for ownership of the chain. He ultimately made the decision to sell to Salinas without seeking other offers. According to inside sources, Salinas has agreed to keep the restaurant’s name as part of the deal. Mr. Benavidez started the business years ago right after finishing school. He opened a small food stand in his hometown",
             "Jacob hated finishing things almost as much as he loved starting them. As a result, he had gotten into a million hobbies and activities, but he never stuck with any of them long enough to get any good",
"He begged his mother for months for a guitar so that he could play Black Eyed Peas songs to Angie, a girl he liked, but after he finally got one for Christmas, he found out that guitars don’t play themselves. He took a few lessons, but strumming the strings hurt his fingers and he didn’t like holding the pick, so now the five hundred dollar guitar lives under his bed",

" i have a problem could you help me solve this problem",
"Open the door i need to talk to you "]}

# %%
from IPython.display import Audio

# %%
x=data["file"][0]

# %%
Audio(x)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'file': ['/content/gdrive/MyDrive/asr _dataset/1.wav',
#   '/content/gdrive/MyDrive/asr _dataset/2.wav',
#   '/content/gdrive/MyDrive/asr _dataset/3.wav',
#   '/content/gdrive/MyDrive/asr _dataset/4.wav',
#   '/content/gdrive/MyDrive/asr _dataset/5.wav',
#   '/content/gdrive/MyDrive/asr _dataset/6.wav',
#   '/content/gdrive/MyDrive/asr _dataset/7.wav',
#   '/content/gdrive/MyDrive/asr _dataset/8.wav',
#   '/content/gdrive/MyDrive/asr _dataset/9.wav',
#   '/content/gdrive/MyDrive/asr _dataset/10.wav',
#   '/content/gdrive/MyDrive/asr _dataset/11.wav',
#   '/content/gdrive/MyDrive/asr _dataset/12.wav',
#   '/content/gdrive/MyDrive/asr _dataset/13.wav',
#   '/content/gdrive/MyDrive/asr _dataset/14.wav',
#   '/content/gdrive/MyDrive/asr _dataset/15.wav',
#   '/content/gdrive/MyDrive/asr _dataset/16.wav',
#   '/content/gdrive/MyDrive/asr _dataset/17.wav',
#   '/content/gdrive/MyDrive/asr _dataset/18.wav',
#   '/content/gdrive/MyDrive/asr _dataset/19.wav',
# ...

# %%
import pandas as pd
data=pd.DataFrame(data)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                                            file                                               text
# 0    /content/gdrive/MyDrive/asr _dataset/1.wav  hello my name is yasmine i was born in ninetee...
# 1    /content/gdrive/MyDrive/asr _dataset/2.wav  i'm a student at national school of engineerin...
# 2    /content/gdrive/MyDrive/asr _dataset/3.wav                                   i'm from tunisia
# 3    /content/gdrive/MyDrive/asr _dataset/4.wav     my father my mother my sister my brother alvia
# 4    /content/gdrive/MyDrive/asr _dataset/5.wav     what's the weather like today let's go camping
# 5    /content/gdrive/MyDrive/asr _dataset/6.wav                              i'm happy i'm excited
# 6    /content/gdrive/MyDrive/asr _dataset/7.wav  welcome evreyone today we talked about speechr...
# 7    /content/gdrive/MyDrive/asr _dataset/8.wav  good morning evreyone and welcome to my presen...
# ...

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## removing special caracters

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'
x=range(len(data))
for i in x : 
  data["text"][i] = re.sub(chars_to_ignore_regex, '', data["text"][i]).lower() + " "

# %%
data["text"]

# %%
data

# %% [markdown]
# # Saving Data

# %%
data.to_csv("data.csv")
